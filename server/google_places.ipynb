# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import time

# Ruta a tu ChromeDriver
driver_path = "C:/Users/Pedro/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe"

# Configura el servicio de Selenium
service = Service(driver_path)

# Inicia el navegador con el servicio configurado
driver = webdriver.Chrome(service=service)

# URL de la página principal
url = "https://www.holaislascanarias.com/playas/"

# Abre la página con Selenium
driver.get(url)
time.sleep(5)  # Espera a que se cargue el contenido dinámico

# Extrae el HTML renderizado
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# Lista para almacenar datos de todas las páginas
data = []

# Función para procesar las playas en la página actual
def procesar_playas(soup):
    playas = soup.find_all("div", class_="wrapper-item")
    for playa in playas:
        try:
            title_tag = playa.find("h3", class_="field__item")
            title = title_tag.get_text(strip=True) if title_tag else "Sin título"

            link_tag = playa.find("a", href=True)
            relative_link = link_tag["href"] if link_tag else None
            full_link = f"https://www.holaislascanarias.com{relative_link}" if relative_link else "Sin enlace"

            island_tag = playa.find("p")
            island = island_tag.get_text(strip=True) if island_tag else "Sin isla"

            img_tag = playa.find("img")
            img_src = img_tag["src"] if img_tag else "Sin imagen"
            full_img_src = f"https://www.holaislascanarias.com{img_src}" if img_src.startswith("/sites/") else img_src

            data.append({
                "title": title,
                "island": island,
                "link": full_link,
                "image": full_img_src
            })

        except Exception as e:
            print(f"Error procesando una playa: {e}")

# Procesa la página inicial
procesar_playas(soup)

# Itera por las páginas siguientes
while True:
    # Encuentra el botón de siguiente página dentro de <li class="next">
    next_button = soup.find("li", class_="next")
    if next_button:
        # Extrae el enlace dentro de <a>
        link_tag = next_button.find("a", href=True)
        if link_tag:
            next_page_url = link_tag["href"]
            print(f"Navegando a la siguiente página: {next_page_url}")
            
            # Carga la nueva página
            driver.get(next_page_url)
            time.sleep(5)
            
            # Extrae el HTML de la nueva página
            html = driver.page_source
            soup = BeautifulSoup(html, "html.parser")
            
            # Procesa las playas en la nueva página
            procesar_playas(soup)
        else:
            break  # No hay más enlaces, termina el bucle
    else:
        break  # No hay más páginas, termina el bucle


# Cierra el navegador
driver.quit()

# Muestra los datos extraídos
for item in data:
    print(item)
# Out:
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=1
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=2
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=3
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=4
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=5
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=6
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=7
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=8
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=9
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=10
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=11
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=12
# Navegando a la siguiente página: https://www.holaislascanarias.com/playas/?resource_type=b_playas&page=13
# {'title': 'Bajamar', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/bajamar/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Bajamar_0.jpg'}
# {'title': 'Playa La Arena', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-la-arena/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-La-Arena_1.jpg'}
# {'title': 'Playa Grande (Puerto del Carmen)', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-grande-puerto-del-carmen/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Grande-Puerto-del-Carmen_0.jpg'}
# {'title': 'Caleta de Mero', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/caleta-de-mero/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Caleta-de-Mero_0.jpg'}
# {'title': 'Playa de Torviscas', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-torviscas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_torviscas.jpg'}
# {'title': 'Playa Puerto de La Estaca', 'island': 'El Hierro', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/el-hierro/playa-puerto-de-la-estaca/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Puerto-de-La-Estaca.jpg'}
# {'title': 'Grandes Playas de Corralejo', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/grandes-playas-de-corralejo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/listado-grandes-playas.jpg'}
# {'title': 'Playa de Chinguarime', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-chinguarime/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/la-gomera_playa-de-chinguarime_01_list.jpg'}
# {'title': 'Playa de Punta Larga', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/playa-de-punta-larga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Punta%20Larga_PH49864.jpg'}
# {'title': 'Playa El Cabrón', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-el-cabron/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/https___turismodecanarias.com_kpi_islascanarias_tiny_images_resize_560x582_PH7746.jpg'}
# {'title': 'Echentive', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/echentive/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Echentive_0.jpg'}
# {'title': 'Antequera', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/antequera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Antequera_0.jpg'}
# {'title': 'Playa de Nogales', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/playa-de-nogales/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Nogales_1.jpg'}
# {'title': 'Las Burras', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/las-burras/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Las-Burras_0.jpg'}
# {'title': 'Playa de Ajuy', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-ajuy/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-de-Ajuy.jpg'}
# {'title': 'El Poris', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-poris/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Grande.jpg'}
# {'title': 'La Garita', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/la-garita/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Garita.jpg'}
# {'title': 'Playa de La Negra', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-negra/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PLAYA-DE-LA-NEGRA-1.jpg'}
# {'title': 'Playa de Ereses', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-ereses/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/ERESE.jpg'}
# {'title': 'Playa de San Marcos', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-san-marcos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-san-marcos_01_list.jpg'}
# {'title': 'Charco Verde', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/charco-verde/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Charco-Verde_0.jpg'}
# {'title': 'Anfi del Mar', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/anfi-del-mar/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/AnfiMAr_0074-list_0.jpg'}
# {'title': 'Esquinzo', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/esquinzo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Esquinzo_0.jpg'}
# {'title': 'Playa de Famara', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-de-famara/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PH1019-list.jpg'}
# {'title': 'Playa de San Sebastián', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-san-sebastian/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-De-San-Sebastian.jpg'}
# {'title': 'Playa de Los Cristianos', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-los-cristianos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Los-Cristianos.jpg'}
# {'title': 'Playa de Guacimeta', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-de-guacimeta/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Guacimeta.jpg'}
# {'title': 'Playa de Santa Catalina', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-santa-catalina/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Santa-Catalina.jpg'}
# {'title': 'Playa de Iguala', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-iguala/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-Iguala.jpg'}
# {'title': 'Playa de Radazul', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-radazul/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-radazul_01_list.jpg'}
# {'title': 'Los Patos', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/los-patos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Patos_002-list_0.jpg'}
# {'title': 'La Tejita', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/la-tejita/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Tejita_002-list_0.jpg'}
# {'title': 'La Concha de Lobos', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/la-concha-de-lobos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Concha-de-lobos_0087-list_0.jpg'}
# {'title': 'Playa de Cofete', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-cofete/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Cofete_0.jpg'}
# {'title': 'Playa de La Cueva', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-cueva/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Cueva.jpg'}
# {'title': 'Playa Bastián', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-bastian/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_playa_bastian.jpg'}
# {'title': 'Playa de Guacimeta', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-de-guacimeta/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Guacimeta.jpg'}
# {'title': 'Playa de Santa Catalina', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-santa-catalina/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Santa-Catalina.jpg'}
# {'title': 'Playa de Iguala', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-iguala/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-Iguala.jpg'}
# {'title': 'Playa de Radazul', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-radazul/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-radazul_01_list.jpg'}
# {'title': 'Los Patos', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/los-patos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Patos_002-list_0.jpg'}
# {'title': 'La Tejita', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/la-tejita/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Tejita_002-list_0.jpg'}
# {'title': 'La Concha de Lobos', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/la-concha-de-lobos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Concha-de-lobos_0087-list_0.jpg'}
# {'title': 'Playa de Cofete', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-cofete/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Cofete_0.jpg'}
# {'title': 'Playa de La Cueva', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-cueva/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Cueva.jpg'}
# {'title': 'Playa Bastián', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-bastian/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_playa_bastian.jpg'}
# {'title': 'Gran Tarajal', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/gran-tarajal/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-De-Gran-Tarajal.jpg'}
# {'title': 'Playa de Alojera', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-alojera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-Alojera.jpg'}
# {'title': 'Playa de Los Pocillos', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-de-los-pocillos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis-playa-los-pocillos.jpg'}
# {'title': 'El Jablillo', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/el-jablillo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-El-Jablillo_0.jpg'}
# {'title': 'Playa de Mogán', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-mogan/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Mogan_0.jpg'}
# {'title': 'Benijo', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/benijo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Benijo-list_0.jpg'}
# {'title': 'Cala de Tacorón', 'island': 'El Hierro', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/el-hierro/cala-de-tacoron/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Cala-de-Tacoron_0.jpg'}
# {'title': 'Sotavento', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/sotavento/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Sotavento_0.jpg'}
# {'title': 'Playa Blanca', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-blanca/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/https___turismodecanarias.com_kpi_islascanarias_tiny_images_resize_560x582_PH45247baja.jpg'}
# {'title': 'Playa Esmeralda', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-esmeralda/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Esmeralda.jpg'}
# {'title': 'Montaña Arena', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/montana-arena/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Montan%CC%83a-Arena.jpg'}
# {'title': 'Playa La Rajita', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-la-rajita/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-La-Rajita.jpg'}
# {'title': 'Playa Honda', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-honda/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/listado_PlayaHonda_desk.jpg'}
# {'title': 'Playa del Tebeto', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-del-tebeto/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/fuerteventura_playa-del-tebeto_01_list.jpg'}
# {'title': 'Playa El Guincho', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-el-guincho/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-del-Guincho_0.jpg'}
# {'title': 'Playa de Punta Larga', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-punta-larga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-punta-larga_01_list.jpg'}
# {'title': 'La Calera', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/la-calera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-la-Calera_0020-1-list.jpg'}
# {'title': 'Puerto Rico', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/puerto-rico/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Puerto-Rico_0.jpg'}
# {'title': 'Playa de Nogales', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/playa-de-nogales/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Nogales_1.jpg'}
# {'title': 'Las Burras', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/las-burras/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Las-Burras_0.jpg'}
# {'title': 'Playa de Ajuy', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-ajuy/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-de-Ajuy.jpg'}
# {'title': 'El Poris', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-poris/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Grande.jpg'}
# {'title': 'La Garita', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/la-garita/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Garita.jpg'}
# {'title': 'Playa de La Negra', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-negra/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PLAYA-DE-LA-NEGRA-1.jpg'}
# {'title': 'Playa de Ereses', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-ereses/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/ERESE.jpg'}
# {'title': 'Playa de San Marcos', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-san-marcos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-san-marcos_01_list.jpg'}
# {'title': 'Playa Grande', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-grande/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Grande_0.jpg'}
# {'title': 'Playa del Risco del Paso', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-del-risco-del-paso/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Risco-del-Paso.jpg'}
# {'title': 'Charco del Palo', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/charco-del-palo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PH22221-list.jpg'}
# {'title': 'Playa de La Guancha', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-guancha/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-del-Guincho.jpg'}
# {'title': 'Playa de La Veta', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/playa-de-la-veta/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Veta_PH49900.jpg'}
# {'title': 'La Pared', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/la-pared/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Pared.jpg'}
# {'title': 'Playa Puerto de Tazacorte', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/playa-puerto-de-tazacorte/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Puerto-de-Tazacorte_0.jpg'}
# {'title': 'El Médano', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-medano/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Medano-list_1.jpg'}
# {'title': 'Costa Calma. Jandía', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/costa-calma-jandia/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Costa-calma_0158-list_0.jpg'}
# {'title': 'Playa de Maspalomas', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-maspalomas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/listado-playa-maspalomas.jpg'}
# {'title': 'El Castillo', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-castillo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_el-castillo_01_list.jpg'}
# {'title': 'Playa de Meloneras', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-meloneras/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_Playa_de_Meloneras_0018.jpg'}
# {'title': 'El Veril', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/el-veril/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PH12502-list.jpg'}
# {'title': 'Playa de Tapahuga', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-tapahuga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Tapahuga.jpg'}
# {'title': 'Playa de Matagorda', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-de-matagorda/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis-playa-de-matagorda.jpg'}
# {'title': 'Playas de Barlovento de Jandía', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playas-de-barlovento-de-jandia/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/fuerteventura_playas-de-barlovento-de-jandia_01_list.jpg'}
# {'title': 'Corralejo Viejo', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/corralejo-viejo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Corralejo-Viejo_0991-list_0.jpg'}
# {'title': 'Amadores', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/amadores/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Amadores_0.jpg'}
# {'title': 'Caletón Blanco', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/caleton-blanco/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Caleton-Blanco_0.jpg'}
# {'title': 'Las Teresitas', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/las-teresitas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PLaya-Teresitas_001-list_0.jpg'}
# {'title': 'Puerto Naos', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/puerto-naos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Puerto-Naos_1.jpg'}
# {'title': 'Playa de Las Alcaravaneras', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-las-alcaravaneras/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_alcaravaneras.jpg'}
# {'title': 'Playa de Patalavaca', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-patalavaca/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Patalavaca.jpg'}
# {'title': 'Las Playas', 'island': 'El Hierro', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/el-hierro/las-playas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Las-Playas.jpg'}
# {'title': 'Playa de Alcalá', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-alcala/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/playa-Alcala_Tenerife.jpg'}
# {'title': 'Playa del Águila', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-del-aguila/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-del-Aguila-%28Puntallana%29.jpg'}
# {'title': 'Playa de Las Arenas', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-las-arenas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-las-arenas_01_list.jpg'}
# {'title': 'Las Vistas', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/las-vistas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Vistas-list_0.jpg'}
# {'title': 'Playa de Las Canteras', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-las-canteras/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Las-Canteras_0.jpg'}
# {'title': 'Playa del Inglés', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-del-ingles/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Ingles_200-1-list_0.jpg'}
# {'title': 'El Verodal', 'island': 'El Hierro', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/el-hierro/el-verodal/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-El-Verodal_0.jpg'}
# {'title': 'El Camisón', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-camison/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-El-Camison.jpg'}
# {'title': 'Arinaga', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/arinaga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Arinaga.jpg'}
# {'title': 'Playa de Los Canarios', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-los-canarios/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PH13176-list.jpg'}
# {'title': 'Playa de La Cantera', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-cantera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-La-Cantera.jpg'}
# {'title': 'Playa El Guincho', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-el-guincho/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-del-Guincho_0.jpg'}
# {'title': 'Playa de La Sepultura', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-sepultura/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-La-Sepultura-%28Vallehermoso%29-%281%29.jpg'}
# {'title': 'Arenas Blancas', 'island': 'El Hierro', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/el-hierro/arenas-blancas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/el-hierro_arenas-blancas_01_list.jpg'}
# {'title': 'Las Cucharas', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/las-cucharas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Cucharas-8-list_0.jpg'}
# {'title': 'San Agustín', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/san-agustin/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-San-Agustin_0.jpg'}
# {'title': 'Guguy', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/guguy/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Gu%CC%88i-Gu%CC%88i_0.jpg'}
# {'title': 'El Duque', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-duque/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-El-Duque_0.jpg'}
# {'title': 'Playa De Troya', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-troya/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis-Playa_de_troya_Tenerife_.jpg'}
# {'title': 'Playa de Las Nieves', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-las-nieves/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/listado-playa-las-nieves.jpg'}
# {'title': 'Playa de Timijiraque', 'island': 'El Hierro', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/el-hierro/playa-de-timijiraque/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Cala-de-Timijiraque.jpg'}
# {'title': 'Playa del Trigo', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-del-trigo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-del-Trigo.jpg'}
# {'title': 'Playa San Marcos', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-san-marcos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis-playa-san-marcos.jpg'}
# {'title': 'Playa de la Arena', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-la-arena/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/https___turismodecanarias.com_kpi_islascanarias_tiny_images_resize_560x582_PH44374baja%281%29.jpg'}
# {'title': 'Playa de Las Canteras', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-las-canteras/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Las-Canteras_0.jpg'}
# {'title': 'Playa del Inglés', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-del-ingles/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-Ingles_200-1-list_0.jpg'}
# {'title': 'El Verodal', 'island': 'El Hierro', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/el-hierro/el-verodal/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-El-Verodal_0.jpg'}
# {'title': 'El Camisón', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-camison/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-El-Camison.jpg'}
# {'title': 'Arinaga', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/arinaga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Arinaga.jpg'}
# {'title': 'Playa de Los Canarios', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-los-canarios/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PH13176-list.jpg'}
# {'title': 'Playa de La Cantera', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-cantera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-La-Cantera.jpg'}
# {'title': 'Playa El Guincho', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-el-guincho/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-del-Guincho_0.jpg'}
# {'title': 'Playa de Punta Larga', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-punta-larga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-punta-larga_01_list.jpg'}
# {'title': 'La Calera', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/la-calera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-la-Calera_0020-1-list.jpg'}
# {'title': 'Puerto Rico', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/puerto-rico/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Puerto-Rico_0.jpg'}
# {'title': 'Playa de Nogales', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/playa-de-nogales/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Nogales_1.jpg'}
# {'title': 'Abama', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/abama/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Abama_0.jpg'}
# {'title': 'La Cocina', 'island': 'La Graciosa', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-graciosa/la-cocina/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Cocina.jpg'}
# {'title': 'Playa de El Burrero', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/playa-de-el-burrero/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_Playa_Burrero_0011.jpg'}
# {'title': 'Playa de Matas Blancas', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-matas-blancas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Matas-Blancas.jpg'}
# {'title': 'Playa de Las Gaviotas', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-las-gaviotas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis-Playa_de_las_gaviotas_Tenerife.jpg'}
# {'title': 'Playa Oroja o La Roja', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-oroja-o-la-roja/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/OROJA.JPG'}
# {'title': 'Playa de Las Malvas', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-de-las-malvas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lanzarote_playa-de-las-malvas_01_list.jpg'}
# {'title': 'La Guirra', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/la-guirra/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Guirra_0.jpg'}
# {'title': 'Butihondo', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/butihondo/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Butihondo.jpg'}
# {'title': 'Las Conchas', 'island': 'La Graciosa', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-graciosa/las-conchas/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-la-Concha_0317_02-list_1.jpg'}
# {'title': 'El Socorro', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-socorro/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-El-Socorro_0.jpg'}
# {'title': 'Playa Mujeres', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/playa-mujeres/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PH741-list.jpg'}
# {'title': 'Arinaga', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/arinaga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Arinaga.jpg'}
# {'title': 'Playa de Los Canarios', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-los-canarios/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PH13176-list.jpg'}
# {'title': 'Playa de La Cantera', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-cantera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-La-Cantera.jpg'}
# {'title': 'Playa El Guincho', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-el-guincho/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-del-Guincho_0.jpg'}
# {'title': 'Playa de Punta Larga', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-punta-larga/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-punta-larga_01_list.jpg'}
# {'title': 'La Calera', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/la-calera/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Playa-de-la-Calera_0020-1-list.jpg'}
# {'title': 'Puerto Rico', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/puerto-rico/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Puerto-Rico_0.jpg'}
# {'title': 'Playa de Nogales', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-palma/playa-de-nogales/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Nogales_1.jpg'}
# {'title': 'Las Burras', 'island': 'Gran Canaria', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/gran-canaria/las-burras/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Las-Burras_0.jpg'}
# {'title': 'Playa de Ajuy', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/fuerteventura/playa-de-ajuy/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-de-Ajuy.jpg'}
# {'title': 'El Poris', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/el-poris/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-Playa-Grande.jpg'}
# {'title': 'La Garita', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/lanzarote/la-garita/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/Imagen-listado-La-Garita.jpg'}
# {'title': 'Playa de La Negra', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-la-negra/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/PLAYA-DE-LA-NEGRA-1.jpg'}
# {'title': 'Playa de Ereses', 'island': 'La Gomera', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/la-gomera/playa-de-ereses/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/ERESE.jpg'}
# {'title': 'Playa de San Marcos', 'island': 'Tenerife', 'link': 'https://www.holaislascanarias.comhttps://www.holaislascanarias.com/playas/tenerife/playa-de-san-marcos/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/tenerife_playa-de-san-marcos_01_list.jpg'}
# {'title': 'Giniginámar', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.201012,-14.074844', 'image': 'Sin imagen'}
# {'title': 'Playa Chica', 'island': 'Lanzarote', 'link': 'https://www.holaislascanarias.comhttps://turismolanzarote.com/playa/playa-chica/', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_playa_chica.jpg'}
# {'title': 'Playa Blanca', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.476687,-13.867099', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/lis_playa_blanca_fuerteventura_.jpg'}
# {'title': 'Playa La Lajita', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.180697,-14.155424', 'image': 'Sin imagen'}
# {'title': 'Playa de Ojos, Punta de Jandia', 'island': 'Fuerteventura', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.062994,-14.521050', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/fuerteventura_la-punta-de-jandia_01_list.jpg'}
# {'title': 'Callejoncito', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.814504,-17.972006', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/https___turismodecanarias.com_kpi_islascanarias_tiny_images_resize_560x582_PH13704.jpg'}
# {'title': 'Poris de Puntagorda', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.753376,-18.004488', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/https___turismodecanarias.com_kpi_islascanarias_tiny_images_resize_560x582_PH45535.jpg'}
# {'title': 'Playa La Salemera', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.569192,-17.761563', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/https___turismodecanarias.com_kpi_islascanarias_tiny_images_resize_560x582_https___turismodecanarias.com_kpi_islascanarias_tiny_images_resize_1920_PH33694baja.jpg'}
# {'title': 'Puerto Espíndola', 'island': 'La Palma', 'link': 'https://www.holaislascanarias.comhttp://www.google.com/maps/place/28.811212,-17.763299', 'image': 'https://www.holaislascanarias.com/sites/default/files/resources/list_image/listado_PuertoEsp%C3%ADndola_desk.jpg'}

# %%
for item in data:
    if item['link'].startswith('/'):
        item['link'] = 'https://www.holaislascanarias.com/playas' + item['link']

# %%
for item in data:
    if '/playas' in item['link']:
        item['link'] = item['link'].replace('/playas', '', 1)

# %%
import json

# Define the output file path
output_file = "data.jsonl"

# Write the data to a JSONL file
with open(output_file, "w", encoding="utf-8") as file:
    for item in data:
        file.write(json.dumps(item) + "\n")

# %%
from bs4 import BeautifulSoup
import requests
import json

# Cargar los datos existentes
with open("data.jsonl", "r") as file:
    beaches = [json.loads(line) for line in file]

# Lista para almacenar playas con enlaces no válidos
invalid_links = []

for beach in beaches:
    try:
        # Verificar si el enlace es válido
        if not beach["link"].startswith("https://www.holaislascanarias.com"):
            print(f"Enlace no válido para {beach['title']}: {beach['link']}")
            invalid_links.append(beach["title"])
            continue  # Saltar esta playa y seguir con la siguiente

        # Solicitar la página de la playa
        response = requests.get(beach["link"])
        soup = BeautifulSoup(response.content, "html.parser")

        # Buscar títulos y descripciones en 'texts-wrapper'
        titles_tags = soup.select("div.texts-wrapper h3.title")
        description_tags = soup.select("div.texts-wrapper p.description")

        # Extraer títulos y descripciones como pares
        titles = [tag.get_text(strip=True) for tag in titles_tags]
        descriptions = [tag.get_text(strip=True) for tag in description_tags]

        # Emparejar títulos y descripciones
        paired_descriptions = [{"title": t, "description": d} for t, d in zip(titles, descriptions)]

        beach["details"] = paired_descriptions if paired_descriptions else "Sin detalles"
        print(f"Detalles extraídos para {beach['title']}")
    except Exception as e:
        print(f"Error extrayendo detalles para {beach['title']}: {e}")
        beach["details"] = "Error al obtener detalles"
        continue

# Guardar los datos actualizados
with open("beaches_updated.jsonl", "w") as file:
    for beach in beaches:
        file.write(json.dumps(beach, ensure_ascii=False) + "\n")

# Guardar la lista de playas con enlaces no válidos
with open("invalid_links.json", "w") as file:
    json.dump(invalid_links, file, ensure_ascii=False, indent=4)

print("Detalles extraídos y guardados en 'beaches_updated.jsonl'")
print("Enlaces no válidos guardados en 'invalid_links.json'")
# Out:
# Detalles extraídos para Bajamar
# Detalles extraídos para Playa La Arena
# Detalles extraídos para Playa Grande (Puerto del Carmen)
# Detalles extraídos para Caleta de Mero
# Detalles extraídos para Playa de Torviscas
# Detalles extraídos para Playa Puerto de La Estaca
# Detalles extraídos para Grandes Playas de Corralejo
# Detalles extraídos para Playa de Chinguarime
# Detalles extraídos para Playa de Punta Larga
# Detalles extraídos para Playa El Cabrón
# Detalles extraídos para Echentive
# Detalles extraídos para Antequera
# Detalles extraídos para Playa de Nogales
# Detalles extraídos para Las Burras
# Detalles extraídos para Playa de Ajuy
# Detalles extraídos para El Poris
# Detalles extraídos para La Garita
# Detalles extraídos para Playa de La Negra
# Detalles extraídos para Playa de Ereses
# Detalles extraídos para Playa de San Marcos
# Detalles extraídos para Charco Verde
# Detalles extraídos para Anfi del Mar
# Detalles extraídos para Esquinzo
# Detalles extraídos para Playa de Famara
# Detalles extraídos para Playa de San Sebastián
# Detalles extraídos para Playa de Los Cristianos
# Detalles extraídos para Playa de Guacimeta
# Detalles extraídos para Playa de Santa Catalina
# Detalles extraídos para Playa de Iguala
# Detalles extraídos para Playa de Radazul
# Detalles extraídos para Los Patos
# Detalles extraídos para La Tejita
# Detalles extraídos para La Concha de Lobos
# Error extrayendo detalles para Playa de Cofete: Exceeded 30 redirects.
# Detalles extraídos para Playa de La Cueva
# Detalles extraídos para Playa Bastián
# Detalles extraídos para Playa de Guacimeta
# Detalles extraídos para Playa de Santa Catalina
# Detalles extraídos para Playa de Iguala
# Detalles extraídos para Playa de Radazul
# Detalles extraídos para Los Patos
# Detalles extraídos para La Tejita
# Detalles extraídos para La Concha de Lobos
# Error extrayendo detalles para Playa de Cofete: Exceeded 30 redirects.
# Detalles extraídos para Playa de La Cueva
# Detalles extraídos para Playa Bastián
# Detalles extraídos para Gran Tarajal
# Detalles extraídos para Playa de Alojera
# Detalles extraídos para Playa de Los Pocillos
# Detalles extraídos para El Jablillo
# Detalles extraídos para Playa de Mogán
# Detalles extraídos para Benijo
# Detalles extraídos para Cala de Tacorón
# Detalles extraídos para Sotavento
# Detalles extraídos para Playa Blanca
# Detalles extraídos para Playa Esmeralda
# Detalles extraídos para Montaña Arena
# Detalles extraídos para Playa La Rajita
# Detalles extraídos para Playa Honda
# Detalles extraídos para Playa del Tebeto
# Detalles extraídos para Playa El Guincho
# Detalles extraídos para Playa de Punta Larga
# Detalles extraídos para La Calera
# Detalles extraídos para Puerto Rico
# Detalles extraídos para Playa de Nogales
# Detalles extraídos para Las Burras
# Detalles extraídos para Playa de Ajuy
# Detalles extraídos para El Poris
# Detalles extraídos para La Garita
# Detalles extraídos para Playa de La Negra
# Detalles extraídos para Playa de Ereses
# Detalles extraídos para Playa de San Marcos
# Detalles extraídos para Playa Grande
# Detalles extraídos para Playa del Risco del Paso
# Detalles extraídos para Charco del Palo
# Detalles extraídos para Playa de La Guancha
# Detalles extraídos para Playa de La Veta
# Detalles extraídos para La Pared
# Detalles extraídos para Playa Puerto de Tazacorte
# Detalles extraídos para El Médano
# Detalles extraídos para Costa Calma. Jandía
# Detalles extraídos para Playa de Maspalomas
# Detalles extraídos para El Castillo
# Detalles extraídos para Playa de Meloneras
# Detalles extraídos para El Veril
# Detalles extraídos para Playa de Tapahuga
# Detalles extraídos para Playa de Matagorda
# Detalles extraídos para Playas de Barlovento de Jandía
# Detalles extraídos para Corralejo Viejo
# Detalles extraídos para Amadores
# Detalles extraídos para Caletón Blanco
# Detalles extraídos para Las Teresitas
# Detalles extraídos para Puerto Naos
# Detalles extraídos para Playa de Las Alcaravaneras
# Detalles extraídos para Playa de Patalavaca
# Detalles extraídos para Las Playas
# Detalles extraídos para Playa de Alcalá
# Detalles extraídos para Playa del Águila
# Detalles extraídos para Playa de Las Arenas
# Detalles extraídos para Las Vistas
# Detalles extraídos para Playa de Las Canteras
# Detalles extraídos para Playa del Inglés
# Detalles extraídos para El Verodal
# Detalles extraídos para El Camisón
# Detalles extraídos para Arinaga
# Detalles extraídos para Playa de Los Canarios
# Detalles extraídos para Playa de La Cantera
# Detalles extraídos para Playa El Guincho
# Detalles extraídos para Playa de La Sepultura
# Detalles extraídos para Arenas Blancas
# Detalles extraídos para Las Cucharas
# Detalles extraídos para San Agustín
# Detalles extraídos para Guguy
# Detalles extraídos para El Duque
# Detalles extraídos para Playa De Troya
# Detalles extraídos para Playa de Las Nieves
# Detalles extraídos para Playa de Timijiraque
# Detalles extraídos para Playa del Trigo
# Detalles extraídos para Playa San Marcos
# Detalles extraídos para Playa de la Arena
# Detalles extraídos para Playa de Las Canteras
# Detalles extraídos para Playa del Inglés
# Detalles extraídos para El Verodal
# Detalles extraídos para El Camisón
# Detalles extraídos para Arinaga
# Detalles extraídos para Playa de Los Canarios
# Detalles extraídos para Playa de La Cantera
# Detalles extraídos para Playa El Guincho
# Detalles extraídos para Playa de Punta Larga
# Detalles extraídos para La Calera
# Detalles extraídos para Puerto Rico
# Detalles extraídos para Playa de Nogales
# Detalles extraídos para Abama
# Detalles extraídos para La Cocina
# Detalles extraídos para Playa de El Burrero
# Detalles extraídos para Playa de Matas Blancas
# Detalles extraídos para Playa de Las Gaviotas
# Detalles extraídos para Playa Oroja o La Roja
# Detalles extraídos para Playa de Las Malvas
# Detalles extraídos para La Guirra
# Detalles extraídos para Butihondo
# Detalles extraídos para Las Conchas
# Detalles extraídos para El Socorro
# Detalles extraídos para Playa Mujeres
# Detalles extraídos para Arinaga
# Detalles extraídos para Playa de Los Canarios
# Detalles extraídos para Playa de La Cantera
# Detalles extraídos para Playa El Guincho
# Detalles extraídos para Playa de Punta Larga
# Detalles extraídos para La Calera
# Detalles extraídos para Puerto Rico
# Detalles extraídos para Playa de Nogales
# Detalles extraídos para Las Burras
# Detalles extraídos para Playa de Ajuy
# Detalles extraídos para El Poris
# Detalles extraídos para La Garita
# Detalles extraídos para Playa de La Negra
# Detalles extraídos para Playa de Ereses
# Detalles extraídos para Playa de San Marcos
# Enlace no válido para Giniginámar: http://www.google.com/maps/place/28.201012,-14.074844
# Enlace no válido para Playa Chica: https://turismolanzarote.com/playa/playa-chica/
# Enlace no válido para Playa Blanca: http://www.google.com/maps/place/28.476687,-13.867099
# Enlace no válido para Playa La Lajita: http://www.google.com/maps/place/28.180697,-14.155424
# Enlace no válido para Playa de Ojos, Punta de Jandia: http://www.google.com/maps/place/28.062994,-14.521050
# Enlace no válido para Callejoncito: http://www.google.com/maps/place/28.814504,-17.972006
# Enlace no válido para Poris de Puntagorda: http://www.google.com/maps/place/28.753376,-18.004488
# Enlace no válido para Playa La Salemera: http://www.google.com/maps/place/28.569192,-17.761563
# Enlace no válido para Puerto Espíndola: http://www.google.com/maps/place/28.811212,-17.763299
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[47], line 45
#      43 with open("beaches_updated.jsonl", "w") as file:
#      44     for beach in beaches:
# ---> 45         file.write(json.dumps(beach, ensure_ascii=False) + "\n")
#      47 # Guardar la lista de playas con enlaces no válidos
#      48 with open("invalid_links.json", "w") as file:
#
# File c:\Python311\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u25cf' in position 1223: character maps to <undefined>

# %%
# Guardar los datos actualizados
with open("beaches_updated.jsonl", "w", encoding="utf-8") as file:
    for beach in beaches:
        file.write(json.dumps(beach, ensure_ascii=False) + "\n")

# Guardar la lista de playas con enlaces no válidos
with open("invalid_links.json", "w", encoding="utf-8") as file:
    json.dump(invalid_links, file, ensure_ascii=False, indent=4)

print("Detalles extraídos y guardados en 'beaches_updated.jsonl'")
print("Enlaces no válidos guardados en 'invalid_links.json'")
# Out:
# Detalles extraídos y guardados en 'beaches_updated.jsonl'
# Enlaces no válidos guardados en 'invalid_links.json'

# %%
#Quitamos las playas que no tienen detalles
beaches_with_details = [beach for beach in beaches if beach.get("details")]

# Editamos el archivo de playas actualizado
with open("beaches_updated.jsonl", "w", encoding="utf-8") as file:
    for beach in beaches_with_details:
        file.write(json.dumps(beach, ensure_ascii=False) + "\n")

# %%
import json
from langchain_ollama import OllamaLLM as Ollama

# %%
# Cargar datos de las playas
with open("beaches_updated.jsonl", "r", encoding="utf-8") as file:
    beaches = [json.loads(line) for line in file]

# Función para generar preguntas y respuestas con Llama 3.2
def generate_qa_with_llama(description, beach_name):
    prompt = f"""
    Genera cinco preguntas relevantes basadas en la siguiente descripción de una playa, junto con sus respuestas. 
    Incluye preguntas sobre ubicación, actividades, características y otros detalles interesantes.

    Nombre de la playa: {beach_name}
    Descripción: {description}

    Salida esperada, no añadas NADA más ni al inicio ni al final, solo las preguntas y respuestas:
    - Pregunta 1: <Pregunta>
      Respuesta 1: <Respuesta>
    - Pregunta 2: <Pregunta>
      Respuesta 2: <Respuesta>
    """
    try:
        model = Ollama(model="llama3.2")
        response_text = model.invoke(prompt)
        print(f"Generando preguntas y respuestas para {beach_name}...")
        return response_text    
    except Exception as e:
        print(f"Error conectando con Llama 3.2: {e}")
        return None

# %%
# Generar preguntas y respuestas para cada playa
qa_pairs = []
for beach in beaches:
    try:
        if "details" in beach and isinstance(beach["details"], list):
            description = " ".join(
                [f"{detail['title']}: {detail['description']}" for detail in beach["details"]]
            )
            qa_output = generate_qa_with_llama(description, beach["title"])
            if qa_output:
                qa_pairs.append({"beach": beach["title"], "qa": qa_output})
        else:
            print(f"El campo 'details' no es una lista en la playa: {beach['title']}")
    except Exception as e:
        print(f"Error procesando la playa {beach['title']}: {e}")
# Guardar los resultados en JSONL
with open("llama_generated_qa.jsonl", "w", encoding="utf-8") as file:
    for qa in qa_pairs:
        file.write(json.dumps(qa, ensure_ascii=False) + "\n")

print("Pares de preguntas y respuestas generados con Llama 3.2.")
# Out:
# Generando preguntas y respuestas para Bajamar...
# Generando preguntas y respuestas para Playa La Arena...
# Generando preguntas y respuestas para Playa Grande (Puerto del Carmen)...
# Generando preguntas y respuestas para Caleta de Mero...
# Generando preguntas y respuestas para Playa de Torviscas...
# Generando preguntas y respuestas para Playa Puerto de La Estaca...
# Generando preguntas y respuestas para Grandes Playas de Corralejo...
# Generando preguntas y respuestas para Playa de Chinguarime...
# Generando preguntas y respuestas para Playa de Punta Larga...
# Generando preguntas y respuestas para Playa El Cabrón...
# Generando preguntas y respuestas para Echentive...
# Generando preguntas y respuestas para Antequera...
# Generando preguntas y respuestas para Playa de Nogales...
# Generando preguntas y respuestas para Las Burras...
# Generando preguntas y respuestas para Playa de Ajuy...
# Generando preguntas y respuestas para El Poris...
# Generando preguntas y respuestas para La Garita...
# Generando preguntas y respuestas para Playa de La Negra...
# Generando preguntas y respuestas para Playa de Ereses...
# Generando preguntas y respuestas para Playa de San Marcos...
# Generando preguntas y respuestas para Charco Verde...
# Generando preguntas y respuestas para Anfi del Mar...
# Generando preguntas y respuestas para Esquinzo...
# Generando preguntas y respuestas para Playa de Famara...
# Generando preguntas y respuestas para Playa de San Sebastián...
# Generando preguntas y respuestas para Playa de Los Cristianos...
# Generando preguntas y respuestas para Playa de Guacimeta...
# Generando preguntas y respuestas para Playa de Santa Catalina...
# Generando preguntas y respuestas para Playa de Iguala...
# Generando preguntas y respuestas para Playa de Radazul...
# Generando preguntas y respuestas para Los Patos...
# Generando preguntas y respuestas para La Tejita...
# Generando preguntas y respuestas para La Concha de Lobos...
# Generando preguntas y respuestas para Playa de La Cueva...
# Generando preguntas y respuestas para Playa Bastián...
# Generando preguntas y respuestas para Playa de Guacimeta...
# Generando preguntas y respuestas para Playa de Santa Catalina...
# Generando preguntas y respuestas para Playa de Iguala...
# Generando preguntas y respuestas para Playa de Radazul...
# Generando preguntas y respuestas para Los Patos...
# Generando preguntas y respuestas para La Tejita...
# Generando preguntas y respuestas para La Concha de Lobos...
# Generando preguntas y respuestas para Playa de La Cueva...
# Generando preguntas y respuestas para Playa Bastián...
# Generando preguntas y respuestas para Gran Tarajal...
# Generando preguntas y respuestas para Playa de Alojera...
# Generando preguntas y respuestas para Playa de Los Pocillos...
# Generando preguntas y respuestas para El Jablillo...
# Generando preguntas y respuestas para Playa de Mogán...
# Generando preguntas y respuestas para Benijo...
# Generando preguntas y respuestas para Cala de Tacorón...
# Generando preguntas y respuestas para Sotavento...
# Generando preguntas y respuestas para Playa Blanca...
# Generando preguntas y respuestas para Playa Esmeralda...
# Generando preguntas y respuestas para Montaña Arena...
# Generando preguntas y respuestas para Playa La Rajita...
# Generando preguntas y respuestas para Playa Honda...
# Generando preguntas y respuestas para Playa del Tebeto...
# Generando preguntas y respuestas para Playa El Guincho...
# Generando preguntas y respuestas para Playa de Punta Larga...
# Generando preguntas y respuestas para La Calera...
# Generando preguntas y respuestas para Puerto Rico...
# Generando preguntas y respuestas para Playa de Nogales...
# Generando preguntas y respuestas para Las Burras...
# Generando preguntas y respuestas para Playa de Ajuy...
# Generando preguntas y respuestas para El Poris...
# Generando preguntas y respuestas para La Garita...
# Generando preguntas y respuestas para Playa de La Negra...
# Generando preguntas y respuestas para Playa de Ereses...
# Generando preguntas y respuestas para Playa de San Marcos...
# Generando preguntas y respuestas para Playa Grande...
# Generando preguntas y respuestas para Playa del Risco del Paso...
# Generando preguntas y respuestas para Charco del Palo...
# Generando preguntas y respuestas para Playa de La Guancha...
# Generando preguntas y respuestas para Playa de La Veta...
# Generando preguntas y respuestas para La Pared...
# Generando preguntas y respuestas para Playa Puerto de Tazacorte...
# Generando preguntas y respuestas para El Médano...
# Generando preguntas y respuestas para Costa Calma. Jandía...
# Generando preguntas y respuestas para Playa de Maspalomas...
# Generando preguntas y respuestas para El Castillo...
# Generando preguntas y respuestas para Playa de Meloneras...
# Generando preguntas y respuestas para El Veril...
# Generando preguntas y respuestas para Playa de Tapahuga...
# Generando preguntas y respuestas para Playa de Matagorda...
# Generando preguntas y respuestas para Playas de Barlovento de Jandía...
# Generando preguntas y respuestas para Corralejo Viejo...
# Generando preguntas y respuestas para Amadores...
# Generando preguntas y respuestas para Caletón Blanco...
# Generando preguntas y respuestas para Las Teresitas...
# Generando preguntas y respuestas para Puerto Naos...
# Generando preguntas y respuestas para Playa de Las Alcaravaneras...
# Generando preguntas y respuestas para Playa de Patalavaca...
# Generando preguntas y respuestas para Las Playas...
# Generando preguntas y respuestas para Playa de Alcalá...
# Generando preguntas y respuestas para Playa del Águila...
# Generando preguntas y respuestas para Playa de Las Arenas...
# Generando preguntas y respuestas para Las Vistas...
# Generando preguntas y respuestas para Playa de Las Canteras...
# Generando preguntas y respuestas para Playa del Inglés...
# Generando preguntas y respuestas para El Verodal...
# Generando preguntas y respuestas para El Camisón...
# Generando preguntas y respuestas para Arinaga...
# Generando preguntas y respuestas para Playa de Los Canarios...
# Generando preguntas y respuestas para Playa de La Cantera...
# Generando preguntas y respuestas para Playa El Guincho...
# Generando preguntas y respuestas para Playa de La Sepultura...
# Generando preguntas y respuestas para Arenas Blancas...
# Generando preguntas y respuestas para Las Cucharas...
# Generando preguntas y respuestas para San Agustín...
# Generando preguntas y respuestas para Guguy...
# Generando preguntas y respuestas para El Duque...
# Generando preguntas y respuestas para Playa De Troya...
# Generando preguntas y respuestas para Playa de Las Nieves...
# Generando preguntas y respuestas para Playa de Timijiraque...
# Generando preguntas y respuestas para Playa del Trigo...
# Generando preguntas y respuestas para Playa San Marcos...
# Generando preguntas y respuestas para Playa de la Arena...
# Generando preguntas y respuestas para Playa de Las Canteras...
# Generando preguntas y respuestas para Playa del Inglés...
# Generando preguntas y respuestas para El Verodal...
# Generando preguntas y respuestas para El Camisón...
# Generando preguntas y respuestas para Arinaga...
# Generando preguntas y respuestas para Playa de Los Canarios...
# Generando preguntas y respuestas para Playa de La Cantera...
# Generando preguntas y respuestas para Playa El Guincho...
# Generando preguntas y respuestas para Playa de Punta Larga...
# Generando preguntas y respuestas para La Calera...
# Generando preguntas y respuestas para Puerto Rico...
# Generando preguntas y respuestas para Playa de Nogales...
# Generando preguntas y respuestas para Abama...
# Generando preguntas y respuestas para La Cocina...
# Generando preguntas y respuestas para Playa de El Burrero...
# Generando preguntas y respuestas para Playa de Matas Blancas...
# Generando preguntas y respuestas para Playa de Las Gaviotas...
# Generando preguntas y respuestas para Playa Oroja o La Roja...
# Generando preguntas y respuestas para Playa de Las Malvas...
# Generando preguntas y respuestas para La Guirra...
# Generando preguntas y respuestas para Butihondo...
# Generando preguntas y respuestas para Las Conchas...
# Generando preguntas y respuestas para El Socorro...
# Generando preguntas y respuestas para Playa Mujeres...
# Generando preguntas y respuestas para Arinaga...
# Generando preguntas y respuestas para Playa de Los Canarios...
# Generando preguntas y respuestas para Playa de La Cantera...
# Generando preguntas y respuestas para Playa El Guincho...
# Generando preguntas y respuestas para Playa de Punta Larga...
# Generando preguntas y respuestas para La Calera...
# Generando preguntas y respuestas para Puerto Rico...
# Generando preguntas y respuestas para Playa de Nogales...
# Generando preguntas y respuestas para Las Burras...
# Generando preguntas y respuestas para Playa de Ajuy...
# Generando preguntas y respuestas para El Poris...
# Generando preguntas y respuestas para La Garita...
# Generando preguntas y respuestas para Playa de La Negra...
# Generando preguntas y respuestas para Playa de Ereses...
# Generando preguntas y respuestas para Playa de San Marcos...
# Pares de preguntas y respuestas generados con Llama 3.2.

# %%
import json

def process_jsonl(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', encoding='utf-8') as outfile:
        for line_number, line in enumerate(infile, start=1):
            try:
                # Cargar la línea como JSON
                data = json.loads(line)

                # Suponiendo que el texto está en la clave 'text'
                text = data.get("qa", "")
                if not text.strip():
                    print(f"Línea {line_number}: 'text' está vacío o no existe.")
                    continue

                # Dividir por saltos de línea y eliminar espacios vacíos
                parts = [part.strip() for part in text.split('\n') if part.strip()]

                # Crear pares prompt-answer
                for i in range(0, len(parts), 2):
                    prompt = parts[i]
                    answer = parts[i + 1] if i + 1 < len(parts) else ""
                    json.dump({"prompt": prompt, "answer": answer}, outfile, ensure_ascii=False)
                    outfile.write('\n')

            except json.JSONDecodeError as e:
                print(f"Línea {line_number}: Error decodificando JSON: {e}")
            except Exception as e:
                print(f"Línea {line_number}: Error inesperado: {e}")

    print("Procesamiento completado. Revisa el archivo de salida.")

if __name__ == "__main__":
    input_file = "llama_generated_qa.jsonl"  # Reemplázalo con el nombre de tu archivo de entrada
    output_file = "output.jsonl"  # Reemplázalo con el nombre del archivo de salida
    process_jsonl(input_file, output_file)
# Out:
# Procesamiento completado. Revisa el archivo de salida.
